# %%
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# # Загрузка данных

# %%
# %%capture
# !wget https://www.dropbox.com/s/64ol9q9ssggz6f1/data_ford_price.xlsx

# %%
data = pd.read_excel('data/data_ford_price.xlsx')

# %% [markdown]
# # Обработка географических данных

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
Latitude = str(data['lat'][0])
Longitude =  str(data['long'][0])
location = geolocator.reverse(Latitude+","+Longitude)
print(location)
# Out:
# Fort Henry Drive, Kingsport, Sullivan County, Tennessee, 37663, United States

# %%
address = location.raw['address']
address
# Out:
# {'road': 'Fort Henry Drive',
#  'city': 'Kingsport',
#  'county': 'Sullivan County',
#  'state': 'Tennessee',
#  'ISO3166-2-lvl4': 'US-TN',
#  'postcode': '37663',
#  'country': 'United States',
#  'country_code': 'us'}

# %% [markdown]
# # Отрисовка карты

# %%
# !pip install geopandas
# !pip install shapely
# Out:
# Collecting geopandas
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: packaging in c:\users\evgen\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely<2,>=1.7 in c:\users\evgen\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (1.8.4)
# Collecting pyproj>=2.6.1.post1
#   Using cached pyproj-3.4.0-cp39-cp39-win_amd64.whl (4.8 MB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\evgen\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (1.4.1)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: shapely in c:\users\evgen\appdata\local\programs\python\python39\lib\site-packages (1.8.4)

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt

# %%
geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
gdf = GeoDataFrame(data, geometry=geometry)  
 
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='green', markersize=15)
 
plt.title('Расположение автомобилей на карте мира')
plt.show()

# %%
import plotly.express as px
 
fig = px.scatter_geo(data,lat='lat',lon='long', hover_name="price")
fig.update_layout(title = 'Интерактивная карта цены автомобиля в зависимости от локации', title_x=1)
fig.show()
